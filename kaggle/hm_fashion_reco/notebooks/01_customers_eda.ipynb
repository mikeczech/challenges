# %%
# %load_ext lab_black

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# # Explore Customer Data

# %%
df_customers = pd.read_csv("../data/customers.csv")

# %%
df_customers
# Out:
#                                                customer_id   FN  Active  \
# 0        00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1        0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3        00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4        00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f... 1.00    1.00
# ...                                                    ...  ...     ...
# 1371975  ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e474...  NaN     NaN
# 1371976  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...  NaN     NaN
# 1371977  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1... 1.00    1.00
# 1371978  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38... 1.00    1.00
# 1371979  ffffd9ac14e89946416d80e791d064701994755c3ab686...  NaN     NaN
#
#         club_member_status fashion_news_frequency   age  \
# ...

# %%
df_customers["customer_id"].nunique()
# Out:
# 1371980

# %%
df_customers.isna().mean().plot.bar(title="NA Ratios")
# Out:
# <AxesSubplot:title={'center':'NA Ratios'}>

# %%
categorical_cols = ["FN", "Active", "club_member_status", "fashion_news_frequency"]

fig, axs = plt.subplots(1, len(categorical_cols), figsize=(20, 4))
for i, c in enumerate(categorical_cols):
    df_customers[c].value_counts().plot.bar(ax=axs[i], title=c)

# %%
df_customers["club_member_status"].unique()
# Out:
# array(['ACTIVE', nan, 'PRE-CREATE', 'LEFT CLUB'], dtype=object)

# %%
df_customers["age"].plot.hist(title="Age", bins=50)
# Out:
# <AxesSubplot:title={'center':'Age'}, ylabel='Frequency'>

# %%
df_customers["age"].describe()
# Out:
# count   1356119.00
# mean         36.39
# std          14.31
# min          16.00
# 25%          24.00
# 50%          32.00
# 75%          49.00
# max          99.00
# Name: age, dtype: float64

# %%
s_postal_code_vc = df_customers["postal_code"].value_counts()
s_postal_code_vc.describe()
# Out:
# count   352899.00
# mean         3.89
# std        202.54
# min          1.00
# 25%          1.00
# 50%          3.00
# 75%          5.00
# max     120303.00
# Name: postal_code, dtype: float64
